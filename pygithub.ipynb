# %%
import pandas as pd
from github import Github
import time

# %%
data_repo = pd.read_csv("fff.csv")
data_repo.head(10)
# Out:
#    Unnamed: 0                                              user
# 0           0                                Python-GUI-Project  \
# 1           1  Hands-on-Microservices-with-Python-Order-Service
# 2           2                      Amazon-Previous-OA-questions
# 3           3             Microsoft.Xrm.Data.PowerShell.Samples
# 4           4                                      chocofactory
# 5           5                                    Final_Projects
# 6           6                              ws-0100-codepen-copy
# 7           7                                 NowIamFeelingThat
# 8           8                                       Defeat-JAVA
# 9           9                                         code_repo
#
#                                                 link
# 0  https://github.com/Aashishkumar123/Python-GUI-...
# 1  https://github.com/PacktPublishing/Hands-on-Mi...
# 2  https://github.com/NoobSolver/Amazon-Previous-...
# 3  https://github.com/seanmcne/Microsoft.Xrm.Data...
# 4       https://github.com/chocomintapp/chocofactory
# 5  https://github.com/epam-js-march-2019/Final_Pr...
# 6  https://github.com/version1-workspace/ws-0100-...
# 7          https://github.com/VoQn/NowIamFeelingThat
# 8        https://github.com/sam-tripathi/Defeat-JAVA
# 9                https://github.com/falwat/code_repo

# %%
# Public repository
g = Github("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")

dict_repo = {"Full name" : [ ],
                 "Description" : [ ],
                 "Date created" : [ ],
                 "Date of last push" : [ ],
                 "Home Page" : [ ],
                 "Language:" : [ ],
                 "Number of forks" : [ ],
                 "Number of stars" : [ ]
            }
count = 0
for link in data_repo["link"]:
    if (count < 100):
        user = link.replace("https://github.com/", "")
        repo = g.get_repo(user)
    
        # repository full name
        #print("Full name:", g.get_repo(repo).full_name)
        dict_repo["Full name"].append(repo.full_name)
    
        # repository description
        #print("Description:", g.get_repo(repo).description)
        dict_repo["Description"].append(repo.description)
    
        # the date of when the repo was created
        #print("Date created:", g.get_repo(repo).created_at)
        dict_repo["Date created"].append(repo.created_at)
    
        # the date of the last git push
        #print("Date of last push:", g.get_repo(repo).pushed_at)
        dict_repo["Date of last push"].append(repo.pushed_at)
    
        # home website (if available)
        #print("Home Page:", g.get_repo(repo).homepage)
        dict_repo["Home Page"].append(repo.homepage)
    
        # programming language
        #print("Language:", g.get_repo(repo).language)
        dict_repo["Language:"].append(repo.language)
    
        # number of forks
        #print("Number of forks:", g.get_repo(repo).forks)
        dict_repo["Number of forks"].append(repo.forks)
    
        # number of stars
        #print("Number of stars:", g.get_repo(repo).stargazers_count)
        #print("-"*50)
        dict_repo["Number of stars"].append(repo.stargazers_count)
        count = count + 1
    else:
        count = 0
        time.sleep(25)
# Out:
# ---------------------------------------------------------------------------
# RateLimitExceededException                Traceback (most recent call last)
# Cell In[12], line 17
#      15 if (count < 100):
#      16     user = link.replace("https://github.com/", "")
# ---> 17     repo = g.get_repo(user)
#      19     # repository full name
#      20     #print("Full name:", g.get_repo(repo).full_name)
#      21     dict_repo["Full name"].append(repo.full_name)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\github\MainClass.py:321, in Github.get_repo(self, full_name_or_id, lazy)
#     317 if lazy:
#     318     return Repository.Repository(
#     319         self.__requester, {}, {"url": url}, completed=False
#     320     )
# --> 321 headers, data = self.__requester.requestJsonAndCheck("GET", url)
#     322 return Repository.Repository(self.__requester, headers, data, completed=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\github\Requester.py:398, in Requester.requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     397 def requestJsonAndCheck(self, verb, url, parameters=None, headers=None, input=None):
# --> 398     return self.__check(
#     399         *self.requestJson(
#     400             verb, url, parameters, headers, input, self.__customConnection(url)
#     401         )
#     402     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\github\Requester.py:423, in Requester.__check(self, status, responseHeaders, output)
#     421 output = self.__structuredFromJson(output)
#     422 if status >= 400:
# --> 423     raise self.__createException(status, responseHeaders, output)
#     424 return responseHeaders, output
#
# RateLimitExceededException: 403 {"message": "API rate limit exceeded for user ID 115733812.", "documentation_url": "https://docs.github.com/rest/overview/resources-in-the-rest-api#rate-limiting"}

# %%
pd.DataFrame(dict_repo).to_csv("data_depot1.csv")

# %%
data_depo = pd.read_csv("data_depot1.csv")
data_depo
# Out:
#       Unnamed: 0                                          Full name
# 0              0                 Aashishkumar123/Python-GUI-Project  \
# 1              1  PacktPublishing/Hands-on-Microservices-with-Py...
# 2              2            NoobSolver/Amazon-Previous-OA-questions
# 3              3     seanmcne/Microsoft.Xrm.Data.PowerShell.Samples
# 4              4                          chocomintapp/chocofactory
# ...          ...                                                ...
# 4995        4995                      psujit775/terraform-templates
# 4996        4996                             Sahil624/Python-Basics
# 4997        4997                      ManjunathACG/Hive-Repositries
# 4998        4998                          YoungForm/GIT_repositries
# 4999        4999               jp-ruth-arundathi/PopularRepositries
#
#                                             Description         Date created
# 0     A Repositry that contains 20+ GUI Projects on ...  2020-06-23 10:21:50  \
# 1                          Repositry for Order Services  2018-11-02 11:05:08
# 2     This repositry contains all the Previous year ...  2021-01-03 14:20:49
# 3     This is samples repositry for Microsoft.Xrm.Da...  2015-11-09 15:56:19
# 4                           This is chocofork repositry  2021-03-13 04:43:58
# ...                                                 ...                  ...
# 4995  This Repositry contains list of terraform temp...  2022-03-19 18:20:13
# 4996                This is Repositry of Python Basics.  2017-02-16 05:05:15
# 4997                                                NaN  2018-09-27 10:26:29
# 4998                                                NaN  2019-02-18 02:48:32
# 4999                                                NaN  2022-06-07 13:10:24
#
#         Date of last push                                          Home Page
# 0     2023-06-11 14:30:45  https://github.com/Aashishkumar123/Python-GUI-...  \
# 1     2023-05-22 21:36:48                                                NaN
# 2     2021-01-03 14:25:18                                                NaN
# 3     2022-06-23 18:13:47  https://github.com/seanmcne/Microsoft.Xrm.Data...
# 4     2022-10-27 05:24:09                                                NaN
# ...                   ...                                                ...
# 4995  2023-02-16 14:06:54                                                NaN
# 4996  2020-10-03 10:02:52                                                NaN
# 4997  2018-09-27 10:26:30                                                NaN
# 4998  2019-02-18 05:27:18                                                NaN
# 4999  2022-06-07 13:13:10                                                NaN
#
#        Language:  Number of forks  Number of stars
# 0         Python              191              387
# 1         Python               23               14
# 2            C++               50              120
# 3     PowerShell               22               48
# 4     TypeScript                4               19
# ...          ...              ...              ...
# 4995         HCL                2                0
# 4996      Python                2                0
# 4997         NaN                0                0
# 4998         NaN                0                0
# 4999  JavaScript                0                0
#
# [5000 rows x 9 columns]
